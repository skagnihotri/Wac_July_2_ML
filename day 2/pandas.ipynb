# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/movie_metadata.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#                                   movie_title  ... title_year
# 0                                      Avatar  ...     2009.0
# 1    Pirates of the Caribbean: At World's End  ...     2007.0
# 2                                     Spectre  ...     2015.0
# 3                       The Dark Knight Rises  ...     2012.0
# 4  Star Wars: Episode VII - The Force Awakens  ...     2015.0
#
# [5 rows x 8 columns]

# %%
df.head(10)
# Out:
#                                   movie_title  ... title_year
# 0                                      Avatar  ...     2009.0
# 1    Pirates of the Caribbean: At World's End  ...     2007.0
# 2                                     Spectre  ...     2015.0
# 3                       The Dark Knight Rises  ...     2012.0
# 4  Star Wars: Episode VII - The Force Awakens  ...     2015.0
# 5                                 John Carter  ...     2012.0
# 6                                Spider-Man 3  ...     2007.0
# 7                                     Tangled  ...     2010.0
# 8                     Avengers: Age of Ultron  ...     2015.0
# 9      Harry Potter and the Half-Blood Prince  ...     2009.0
#
# [10 rows x 8 columns]

# %%
df.tail()
# Out:
#                       movie_title       director_name  ... country  title_year
# 4927        This Is Martin Bonner       Chad Hartigan  ...     USA      2013.0
# 4928                 A True Story     Malcolm Goodwin  ...     USA      2013.0
# 4929            George Washington  David Gordon Green  ...     USA      2000.0
# 4930  Smiling Fish & Goat on Fire        Kevin Jordan  ...     USA      1999.0
# 4931    Dawn of the Crescent Moon         Kirk Loudon  ...     USA      2014.0
#
# [5 rows x 8 columns]

# %%
df.tail(7)
# Out:
#                       movie_title       director_name  ... country  title_year
# 4925                   The Signal      William Eubank  ...     USA      2014.0
# 4926         The Image Revolution      Patrick Meaney  ...     USA      2014.0
# 4927        This Is Martin Bonner       Chad Hartigan  ...     USA      2013.0
# 4928                 A True Story     Malcolm Goodwin  ...     USA      2013.0
# 4929            George Washington  David Gordon Green  ...     USA      2000.0
# 4930  Smiling Fish & Goat on Fire        Kevin Jordan  ...     USA      1999.0
# 4931    Dawn of the Crescent Moon         Kirk Loudon  ...     USA      2014.0
#
# [7 rows x 8 columns]

# %%
df.shape
# Out:
# (4932, 8)

# %%
df.shape[0]
# Out:
# 4932

# %%
df.shape[1]
# Out:
# 8

# %%
df.columns
# Out:
# Index(['movie_title', 'director_name', 'color', 'duration', 'actor_1_name',
#        'language', 'country', 'title_year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4932 entries, 0 to 4931
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_title    4932 non-null   object
#  1   director_name  4831 non-null   object
#  2   color          4916 non-null   object
#  3   duration       4918 non-null   float64
#  4   actor_1_name   4926 non-null   object
#  5   language       4922 non-null   object
#  6   country        4930 non-null   object
#  7   title_year     4829 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 308.4+ KB

# %%
df.describe()
# Out:
#           duration   title_year
# count  4918.000000  4829.000000
# mean    107.344856  2002.478981
# std      24.986753    12.447114
# min       7.000000  1916.000000
# 25%      93.000000  1999.000000
# 50%     103.500000  2005.000000
# 75%     118.000000  2011.000000
# max     511.000000  2016.000000

# %%
df.corr()
# Out:
#             duration  title_year
# duration    1.000000   -0.130795
# title_year -0.130795    1.000000

# %%
df.head()
# Out:
#                                   movie_title  ... title_year
# 0                                      Avatar  ...     2009.0
# 1    Pirates of the Caribbean: At World's End  ...     2007.0
# 2                                     Spectre  ...     2015.0
# 3                       The Dark Knight Rises  ...     2012.0
# 4  Star Wars: Episode VII - The Force Awakens  ...     2015.0
#
# [5 rows x 8 columns]

# %%
df['movie_title']
# Out:
# 0                                           Avatar
# 1         Pirates of the Caribbean: At World's End
# 2                                          Spectre
# 3                            The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens
#                            ...
# 4927                         This Is Martin Bonner
# 4928                                  A True Story
# 4929                             George Washington
# 4930                   Smiling Fish & Goat on Fire
# 4931                     Dawn of the Crescent Moon
# Name: movie_title, Length: 4932, dtype: object

# %%
df.movie_title
# Out:
# 0                                           Avatar
# 1         Pirates of the Caribbean: At World's End
# 2                                          Spectre
# 3                            The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens
#                            ...
# 4927                         This Is Martin Bonner
# 4928                                  A True Story
# 4929                             George Washington
# 4930                   Smiling Fish & Goat on Fire
# 4931                     Dawn of the Crescent Moon
# Name: movie_title, Length: 4932, dtype: object

# %%
df.get('movie_title')
# Out:
# 0                                           Avatar
# 1         Pirates of the Caribbean: At World's End
# 2                                          Spectre
# 3                            The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens
#                            ...
# 4927                         This Is Martin Bonner
# 4928                                  A True Story
# 4929                             George Washington
# 4930                   Smiling Fish & Goat on Fire
# 4931                     Dawn of the Crescent Moon
# Name: movie_title, Length: 4932, dtype: object

# %%
df.nunique()
# Out:
# movie_title      4808
# director_name    2345
# color               2
# duration          190
# actor_1_name     2035
# language           46
# country            63
# title_year         91
# dtype: int64

# %%
X = df.values

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X[:10]
# Out:
# array([['Avatar', 'James Cameron', 'Color', 178.0, 'CCH Pounder',
#         'English', 'USA', 2009.0],
#        ["Pirates of the Caribbean: At World's End", 'Gore Verbinski',
#         'Color', 169.0, 'Johnny Depp', 'English', 'USA', 2007.0],
#        ['Spectre', 'Sam Mendes', 'Color', 148.0, 'Christoph Waltz',
#         'English', 'UK', 2015.0],
#        ['The Dark Knight Rises', 'Christopher Nolan', 'Color', 164.0,
#         'Tom Hardy', 'English', 'USA', 2012.0],
#        ['Star Wars: Episode VII - The Force Awakens', 'JJ Abrams',
#         'Color', 136.0, 'Harrison Ford', 'English', 'USA', 2015.0],
#        ['John Carter', 'Andrew Stanton', 'Color', 132.0, 'Daryl Sabara',
#         'English', 'USA', 2012.0],
#        ['Spider-Man 3', 'Sam Raimi', 'Color', 156.0, 'J.K. Simmons',
#         'English', 'USA', 2007.0],
#        ['Tangled', 'Nathan Greno', 'Color', 100.0, 'Brad Garrett',
#         'English', 'USA', 2010.0],
# ...

# %%
df1 = pd.DataFrame(X)

# %%
df1.head()
# Out:
#                                             0                  1  ...    6     7
# 0                                      Avatar      James Cameron  ...  USA  2009
# 1    Pirates of the Caribbean: At World's End     Gore Verbinski  ...  USA  2007
# 2                                     Spectre         Sam Mendes  ...   UK  2015
# 3                       The Dark Knight Rises  Christopher Nolan  ...  USA  2012
# 4  Star Wars: Episode VII - The Force Awakens          JJ Abrams  ...  USA  2015
#
# [5 rows x 8 columns]

# %%
colour = df['color'].values

# %%
colour[:10]
# Out:
# array(['Color', 'Color', 'Color', 'Color', 'Color', 'Color', 'Color',
#        'Color', 'Color', 'Color'], dtype=object)

# %%
s = set()
s
# Out:
# set()

# %%
# s.add(1)
# s

# %%
for i in colour:
    s.add(i)

# %%
s
# Out:
# {' Black and White', 'Color', nan}
